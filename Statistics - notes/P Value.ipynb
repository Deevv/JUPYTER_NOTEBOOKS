# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1

# %%
weight_lost_a = [3,2,3,4,3,2, 2, 2, 1, 3, 2, 3, 1, 3, 4, 1, 3, 2, 1, 3, 4, 3, 2, 3, 7, 2, 3, 2, 5, 1, 1, 1, 3, 2, 4, 10, 2, 3, 2, 5, 6, 2, 3, 2, 3, 4, 1, 3, 3, 1]

# %%
weight_lost_b = [5, 4, 5, 5, 4, 5, 7, 5, 4, 3, 3, 5, 10, 3, 4, 9, 7, 6, 9, 4, 2, 5, 7, 7, 7, 5, 4, 8, 9, 6, 7, 6, 7, 6, 3, 5, 5, 4, 2, 3, 3, 5, 6, 9, 7, 6, 4, 5, 4, 3]

# %%
mean_group_a = np.mean(weight_lost_a)
mean_group_b = np.mean(weight_lost_b)

plt.hist(weight_lost_a)
plt.show()
plt.hist(weight_lost_b)
plt.show()

# %%
mean_group_a
# Out:
# 2.8199999999999998

# %%
mean_group_b
# Out:
# 5.3399999999999999

# %% [markdown]
# ### 2

# %%
mean_difference = mean_group_b - mean_group_a
mean_difference
# Out:
# 2.52

# %% [markdown]
# ### 3 [Sampling Distribution]

# %%
all_values = weight_lost_a + weight_lost_b

# %% [markdown]
# 1000 razy losowa dystybucja wartosci z listy values to dwóch list. Różnica średnich tych list dodawana do kolejnej listy - mean_differences.

# %%
mean_differences = []
for i in range(1000):
    group_a = []
    group_b = []
    for value in all_values:
        assignment_chance = np.random.rand()
        if assignment_chance >= 0.5:
            group_a.append(value)
        else:
            group_b.append(value)
    iteration_mean_difference = np.mean(group_b) - np.mean(group_a)
    mean_differences.append(iteration_mean_difference)
    
plt.hist(mean_differences)
plt.show()

# %% [markdown]
# ### 4

# %%
sampling_distribution = {}
for df in mean_differences:
    if sampling_distribution.get(df, False):
        sampling_distribution[df] = sampling_distribution[df] + 1
    else:
        sampling_distribution[df] = 1

# %%
sampling_distribution
# Out:
# {-1.4303030303030297: 1,
#  -1.275641025641026: 1,
#  -1.1999999999999997: 1,
#  -1.1948470209339774: 1,
#  -1.155555555555555: 1,
#  -1.1336812525090325: 1,
#  -1.1151515151515152: 1,
#  -1.0863993385696573: 1,
#  -1.0666666666666669: 1,
#  -1.059422750424448: 1,
#  -1.0436174469787916: 1,
#  -1.0: 1,
#  -0.99714402284781745: 1,
#  -0.99393939393939412: 1,
#  -0.95718287314925954: 1,
#  -0.95454545454545459: 1,
#  -0.93923108722612625: 1,
#  -0.93548387096774199: 1,
#  -0.92788461538461542: 1,
#  -0.9235694277711084: 1,
#  -0.9210417527904089: 1,
#  -0.91716686674669878: 1,
#  -0.9155446756425949: 1,
#  -0.91396103896103842: 1,
#  -0.89855072463768115: 1,
#  -0.89281413087113615: 2,
#  -0.88782051282051322: 1,
#  -0.88355342136854764: 1,
#  -0.87999999999999945: 2,
#  -0.8735447611401046: 3,
#  -0.87278582930756876: 1,
#  -0.84353741496598689: 1,
#  -0.83713485394157683: 1,
#  -0.81803542673107854: 1,
#  -0.80623973727422005: 1,
#  -0.80000000000000027: 1,
# ...

# %% [markdown]
# ### 5 [p value]

# %% [markdown]
# p value - tablica sampling_distribution zawiera równice między średnimi wartościami dwóch list, do których losowo zostały rozmieszone wszystkie elementy z pierwotnych list. Wartość p to liczba różnic, które są równe lub wiekszę niż różnica między średnimi wartościami w pierwotych listach (2,52) podzielona przez liczbę elementów w sampling_distribution (1000).

# %%
frequencies = []
for sp in sampling_distribution.keys():
    if sp >= 2.52:
        frequencies.append(sp)
p_value = np.sum(frequencies) / 1000
p_value
# Out:
# 0.0

# %% [markdown]
# Warto przyjąć threshold dla wartości p, zazwyczaj będziedzie to ,05
